# %%
#Q1
units = float(input("Enter the total units: "))
total = 0

if units >= 50:
    total += 50 * 0.5
elif units > 0:
    total += units * 0.5

units -= 50

if units >= 100:
    total += 100 * 0.75
elif units > 0:
    total += units * 0.75

units -= 100

if units >= 100:
    total += 100 * 1.2
elif units > 0:
    total += units * 1.2

units -= 100

if units > 0:
    total += units * 1.5

total += total * 0.2
print("Total electricity bill:", total)
# Out:
# Enter the total units:  239
# Total electricity bill: 248.16000000000003

# %%
#Q2
num = int(input("Enter a number: "))

if num % 10 % 3 == 0:
    print("The last digit of the number is divisible by 3")
else:
    print("The last digit of the number is not divisible by 3")
# Out:
# Enter a number:  689
# The last digit of the number is divisible by 3

# %%
#Q3
num = int(input("Enter a number: "))

if num % 35 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Enter a number:  70
# Hello

# %%
#Q4
salary = float(input("Enter the salary: "))
years = int(input("Enter the no. of years: "))

if years > 10:
    bonus = salary * 0.1
elif years > 6:
    bonus = salary * 0.08
elif years >= 0:
    bonus = salary * 0.05
else:
    bonus = 0

print("Net bonus:", bonus)
# Out:
# Enter the salary:  78000
# Enter the no. of years:  8
# Net bonus: 6240.0

# %%
#Q5
num = int(input("Enter a number: "))

if num % 15 == 0:
    print("FizzBuz")
elif num % 3 == 0:
    print("Fizz")
elif num % 5 == 0:
    print("Buzz")
else:
    print(num)
# Out:
# Enter a number:  45
# FizzBuz

# %%
#Q6
speed = float(input("Enter the speed of the driver: "))

if speed < 70:
    print("OK")
elif speed >= 0:
    points = int(speed - 70) // 5
    print("Points:", points)

    if points > 12:
        print("License Suspended")
else:
    print("Speed cannot be negative")
# Out:
# Enter the speed of the driver:  135
# Points: 13
# License Suspended

# %%
#Q7
y=int(input("enter a year : "))
if(((y%4==0) and (y%100!=0)) or (((y%4==0) and (y%100==0)) and(y%400==0))):
    print("leap year! ")
# Out:
# enter a year : 5636
# leap year!

# %%
#Q9
print("input the 3 sides of the triangle :")
a=int(input("side one : "))
b=int(input("side two : "))
c=int(input("side three : "))
if((a+b>c) and (b+c>a) and (a+c>b)):
    if(a==b==c):
        print("equilateral")
    elif(a==b or b==c or a==c):
        print("isosceles")
    else:
        print("Scalene")
else:
    print("not a valid triangle")
# Out:
# input the 3 sides of the triangle :
# side one : 56
# side two : 78
# side three : 56
# isosceles

# %%
#Q10
age=int(input("enter age: "))
if (age<12):
    tc=5
elif(age<18):
    tc=10
elif(age<60):
    tc=20
elif(age>=60):
    tc=15
    
print("The ticket price is :",tc)
# Out:
# enter age: 16
# The ticket price is : 10

# %%
#Q11
"""
Let, x be the no. of Two-Wheelers that needs to be manufactured
and, y be the no. of Four-Wheelers that needs to be manufactured

According to the question,
=> x + y = v            (I)
=> 2x + 4y = w          (II)

From equation I, we get
=> x = v - y            (III)

Substituting the value of x from equation III into equation II, we get
=> 2(v - y) + 4y = w
=> 2v - 2y + 4y = w
=> 2y = -2v + w
=> y = (w - 2v) / 2
=> y = w / 2 - v        (IV)

Substituting the value of y from equation IV into equation I, we get
=> x = v - (w / 2 - v)
=> x = v - w / 2 + v
=> x = 2v - w / 2       (V)

Therefore, from equation IV and V, we get
x = 2v - w / 2          and,
y = w / 2 - v
"""

v = int(input("Enter total no. vehicles: "))
w = int(input("Enter the total no. of wheels: "))
print("Total Two-Wheeler needs to be manufactured:", 2 * v - w // 2)
print("Total Four-Wheeler needs to be manufactured:", w // 2 - v)
# Out:
# Enter total no. vehicles:  90
# Enter the total no. of wheels:  300
# Total Two-Wheeler needs to be manufactured: 30
# Total Four-Wheeler needs to be manufactured: 60

# %%
#Q12
n = int(input("Enter a number: "))
if n & 1 == 0:
    print(n, "is an even number")
else:
    print(n, "is an odd number")
# Out:
# Enter a number:  79
# 79 is an odd number

# %%
## Q13
n = int(input("Enter a number: "))
if n & (n - 1) == 0:
    print(n, "is a power of 2")
else:
    print(n, "is not a power of 2")
# Out:
# Enter a number:  256
# 256 is a power of 2
