# %%
a=int(input("enter 1st no."))
b=int(input("enter 2nd no."))

sum=a+b
print("sum is: ",sum)
diff=a-b
print("difference is ",diff)
prod=a*b
print("product is: ",prod)
quot=a/b
print("quotient is: ",quot)
# Out:
# enter 1st no.45
# enter 2nd no.55
# sum is:  100
# difference is  -10
# product is:  2475
# quotient is:  0.8181818181818182

# %%
a=int(input("enter 1st no."))
b=int(input("enter 2nd no."))

remainder=(a%b)
print("the remainder is: ",remainder)
# Out:
# enter 1st no.23
# enter 2nd no.5
# the remainder is:  3

# %%
a=int(input("enter a no."))
sq=(a*a)
print("the square is: ",sq)
cb=(a*a*a)
print("the cube is: ",cb)
# Out:
# enter a no.5
# the square is:  25
# the cube is:  125

# %%
a=int(input("enter 1st no."))
b=int(input("enter 2nd no."))
c=int(input("enter 3rd no."))
avg=(a+b+c)/3
print("the avg is: ",avg)
# Out:
# enter 1st no.10
# enter 2nd no.20
# enter 3rd no.30
# the avg is:  20.0

# %%
ts=int(input("enter total seconds"))
m=ts//60
s=ts%60
print("min is :",m,"seconds are :",s)
# Out:
# enter total seconds123
# min is : 2 seconds are : 3

# %%
r=int(input("enter radius "))
area=3.14*r*r
print(area)
# Out:
# enter radius 5
# 78.5

# %%
a=int(input("enter p "))
b=int(input("enter r "))
c=int(input("enter t "))
si = (a*b*c)/100
print(si)
# Out:
# enter p 1200
# enter r 10
# enter t 1
# 120.0

# %%
a=int(input("enter 1st no."))
b=int(input("enter exponent no."))
p=a**b
print(p)
# Out:
# enter 1st no.5
# enter exponent no.3
# 125

# %%
a=int(input("enter a no."))
ld=a%10
print("last digit is :",ld)
# Out:
# enter a no.234567
# last digit is : 7

# %%
a=int(input("enter 1st sub marks "))
b=int(input("enter 2nd sub marks "))
c=int(input("enter 3rd sub marks "))
d=int(input("enter 4th sub marks "))
e=int(input("enter 5th sub marks "))
ta=(a+b+c+d+e)
print("total marks are: ",ta)
p=(ta/500)*100
print("percentage is: ",p)
# Out:
# enter 1st sub marks 90
# enter 2nd sub marks 90
# enter 3rd sub marks 90
# enter 4th sub marks 9
# enter 5th sub marks 90
# total marks are:  369
# percentage is:  73.8

# %%
a=int(input("enter a no."))
b=int(input("enter the value to add"))
a+=b
print(a)
c=int(input("enter the value to multiply"))
a*=c
print(a)
# Out:
# enter a no.5
# enter the value to add10
# 15
# enter the value to multiply8
# 120

# %%
a=int(input("enter a no."))
r=(a+10)*2
print("result is :",r)
# Out:
# enter a no.6
# result is : 32

# %%
a=int(input("enter a no."))
b=int(input("enter the no. to divide"))
a//=b
print(a)
# Out:
# enter a no.53
# enter the no. to divide5
# 10

# %%
a=int(input("enter 1st no."))
b=int(input("enter 2nd no."))
a=a+b
b=a-b
a=a-b
print(a,b)
# Out:
# enter 1st no.45
# enter 2nd no.55
# 55 45

# %%
a=int(input("enter a no."))
b=int(input("enter the no. to divide"))
a%=b
print(a)
# Out:
# enter a no.80
# enter the no. to divide5
# 0

# %%
print("enter the 3 co-efficients")
a=int(input("enter 1st no."))
b=int(input("enter 2nd no."))
c=int(input("enter 3rd no."))
d=((b*b)-4*a*c)**0.5
if(d!=0):
    r1=(-b+d)/2*a
    print("1st root: ",r1)
    r2=(-b-d)/2*a
    print("1st root: ",r2)
else:
    print("determinant is 0")
# Out:
# enter the 3 co-efficients
# enter 1st no.4
# enter 2nd no.5
# enter 3rd no.6
# 1st root:  (-9.999999999999998+16.852299546352718j)
# 1st root:  (-10.000000000000002-16.852299546352718j)

# %%
bs=int(input("enter the basic salary"))
da=bs*0.5
hra=bs*0.2
gs=bs+da+hra
print(gs)
# Out:
# enter the basic salary50000
# 85000.0

# %%
f=float(input("enter the temp in fahrenheit"))
c=(5/9)*(f-32)
print(c)
c1=float(input("enter the temp in celsius"))
f1=(9/5)*c1+32
print(f1)
# Out:
# enter the temp in fahrenheit212
# 100.0
# enter the temp in celsius100
# 212.0

# %%
a=int(input("enter a no."))
sum=(a*(a+1))/2
print(sum)
# Out:
# enter a no.6
# 21.0

# %%
a=int(input("enter 1st no."))
b=int(input("enter 2nd no."))
print("logical")
print(a and b)
print(a or b)
print(a is not b)
print("bitwise")
print(a|b)
print(a&b)
print(~a)
print(~b)
print(a>>b)
print(a<<b)
print(a^b)
# Out:
# enter 1st no.16
# enter 2nd no.2
# logical
# 2
# 16
# True
# bitwise
# 18
# 0
# -17
# -3
# 4
# 64
# 18
